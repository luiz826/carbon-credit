# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Emissões de $CO_2$
#
# CO₂ emissions; CO₂ direct and indirect emissions per unit of output by industry and by country. CO₂ emissions by industry, in aggregate terms and in terms of output by industry

# %%
df = pd.read_csv("./raw-data/emissoes_co2.csv")

# %%
relevant_cols = [
    "Country",
    "Indicator",
    "Industry",
    "Unit",
]
relevant_cols.extend([f"F{i}" for i in range(1995, 2019)])

df_rel = df[relevant_cols]

# %%
all_segments = df_rel[[
    "Country",
    "Indicator",
    "Industry",
    "Unit",
]]

# %%
result = np.array()

for row in df_rel.values:    
    segments = row[:4]
    vals = row[4:]
    n_years = len(vals)
    pivoted = np.c_[np.array([segments.tolist()]*n_years), np.arange(1995, 2019), vals]
    result.append(pivoted, axis=0)
    print(len(result))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/luiz/Documents/UFPB/dataviz/carbon-credit/ecdv3/preprocessing.ipynb Cell 7 in 1
# ----> <a href='vscode-notebook-cell:/home/luiz/Documents/UFPB/dataviz/carbon-credit/ecdv3/preprocessing.ipynb#X53sZmlsZQ%3D%3D?line=0'>1</a> result = np.array()
#       <a href='vscode-notebook-cell:/home/luiz/Documents/UFPB/dataviz/carbon-credit/ecdv3/preprocessing.ipynb#X53sZmlsZQ%3D%3D?line=2'>3</a> for row in df_rel.values:
#       <a href='vscode-notebook-cell:/home/luiz/Documents/UFPB/dataviz/carbon-credit/ecdv3/preprocessing.ipynb#X53sZmlsZQ%3D%3D?line=3'>4</a>     segments = row[:4]
#
# TypeError: array() missing required argument 'object' (pos 0)

# %%
np.c_[result].shape
# Out:
# (8910, 24, 6)

# %%
df2 = pd.read_csv("./raw-data/floresta_e_carbono_POTENCIAL.csv")

# %%
relevant_cols = [
    "Country",
    "Indicator",
    "Unit"
]
relevant_cols.extend([f"F{i}" for i in range(1992, 2021)])

df2_rel = df2[relevant_cols]

# %%
df2_rel
# Out:
#                  Country                          Indicator            Unit  \
# 0     Advanced Economies           Carbon stocks in forests  Million tonnes
# 1     Advanced Economies                        Forest area         1000 HA
# 2     Advanced Economies  Index of carbon stocks in forests           Index
# 3     Advanced Economies             Index of forest extent           Index
# 4     Advanced Economies                          Land area         1000 HA
# ...                  ...                                ...             ...
# 1348            Zimbabwe                        Forest area         1000 HA
# 1349            Zimbabwe  Index of carbon stocks in forests           Index
# 1350            Zimbabwe             Index of forest extent           Index
# 1351            Zimbabwe                          Land area         1000 HA
# 1352            Zimbabwe               Share of forest area         Percent
#
#              F1992         F1993         F1994         F1995         F1996  \
# 0     5.261866e+04  5.317770e+04  5.339357e+04  5.360944e+04  5.382531e+04
# 1     9.458406e+05  9.506288e+05  9.508836e+05  9.511385e+05  9.513934e+05
# 2     1.000000e+02  1.010624e+02  1.014727e+02  1.018829e+02  1.022932e+02
